# %%
fileName = 'input\\10.txt'
fileNameTest = 'input\\10test.txt'
data = [int(line.rstrip('\n')) for line in open(fileName)]
data2 = [16,10,15,5,1,11,7,19,6,12,4]
data3 = [int(line.rstrip('\n')) for line in open(fileNameTest)]
data = data
data.append(max(data)+3)
data.append(0)
data = sorted(data)
print(data, len(data))
# Out:
# [0, 1, 2, 5, 8, 9, 10, 11, 14, 17, 20, 21, 22, 23, 24, 27, 30, 31, 32, 33, 34, 37, 38, 39, 40, 43, 46, 47, 48, 49, 50, 53, 54, 55, 56, 57, 60, 63, 64, 65, 66, 67, 70, 71, 72, 73, 74, 77, 78, 79, 80, 83, 84, 85, 86, 87, 90, 91, 92, 95, 96, 97, 98, 99, 102, 103, 104, 105, 106, 109, 110, 111, 112, 113, 116, 117, 118, 119, 120, 123, 124, 125, 126, 127, 130, 131, 132, 133, 136, 137, 140, 143, 146, 147, 148, 151, 154, 155, 158] 99

# %%
from collections import defaultdict
def p10b2(adapters):
    stepping = defaultdict(list)
    for a in adapters:
        steps = [adapter for adapter in adapters if adapter <= a-3 and adapter > a]
        stepping[a] = steps
    for a in adapters:
        
    return 
print(p10b2(data))
# Out:
#   File "<ipython-input-65-28086bebfd6d>", line 9
#     return
#          ^
# IndentationError: expected an indented block

# %%
def p10b(steps, mem={}, n=0):
    muts = sum(1 if m == max(list(steps.keys())) else mem[m] if m in mem else p10b(steps, mem, m) for m in steps[n])
    if n not in mem:
        mem[n] = muts
    return muts

print(p10b({a:[adapter for adapter in adapters if adapter <= a+3 and adapter > a] for a in data}))
# Out:
# 28346956187648

# %%
lut = {}
def m(k,stop,deps):
    if k == stop: # this is the only ending path that is valid
        return 1
    elif k in lut:
        return lut[k]
    else:
        val = sum(m(n,stop,deps) for n in deps[k])
        lut[k] = val
        # print(f"k={k}, deps={deps[k]}, m({k}) = {val}")
        return val

def part2(d):
    deps = dict.fromkeys(d, {})
    for node in deps.keys():
        deps[node] = {a for a in deps.keys() if node + 1 <= a <= node + 3 }
    
    stop = list(deps.keys())[-1]
    print(stop)
    return m(0,stop,deps)

print(part2(set(data)))
# Out:
# 158
# 28346956187648

# %%
distinct_connects = 0
adapters = data
def p10b(index=0):
    global distinct_connects
    next_steps = [adapters.index(adapter) for adapter in adapters if adapter >= adapters[index]-3 and adapter < adapters[index]]
    if next_steps:
        for n in next_steps:
            p10b(n)
    else:
        distinct_connects +=1
#%timeit p10b(data)
#print(data)
p10b(len(adapters)-1)
print(distinct_connects)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-3909a79db5d2> in <module>
#      11 #%timeit p10b(data)
#      12 #print(data)
# ---> 13 p10b(len(adapters)-1)
#      14 print(distinct_connects)
#
# <ipython-input-56-3909a79db5d2> in p10b(index)
#       6     if next_steps:
#       7         for n in next_steps:
# ----> 8             p10b(n)
#       9     else:
#      10         distinct_connects +=1
#
# <ipython-input-56-3909a79db5d2> in p10b(index)
#       6     if next_steps:
#       7         for n in next_steps:
# ----> 8             p10b(n)
#       9     else:
#      10         distinct_connects +=1
#
# <ipython-input-56-3909a79db5d2> in p10b(index)
#       6     if next_steps:
#       7         for n in next_steps:
# ----> 8             p10b(n)
#       9     else:
#      10         distinct_connects +=1
#
# <ipython-input-56-3909a79db5d2> in p10b(index)
# ...
